# %% [markdown]
# IMPORTING DATASETS

# %%
import pandas as pd
Tahanan = pd.read_csv('C:/Users/asus/Desktop/SK5A/Berkas Kerja Praktik/DataSetTahanan.csv')
print(Tahanan)
# Out:
#                 Nama                                     Kasus  \
# 0      Rahman Antoni                                 Narkotika
# 1        PEBI IRAWAN            Lalu Lintas dan Angkutan Jalan
# 2       Erik Saputra                                      KUHP
# 3              Suadi                                 Narkotika
# 4         Edi Sapari                                 Narkotika
# ..               ...                                       ...
# 73   CECEP SUPRIYADI  Penghapusan Kekerasan Dalam Rumah Tangga
# 74      AKIB IBRAHIM  Penghapusan Kekerasan Dalam Rumah Tangga
# 75  ROBBAL NUR ROHIM                                 Narkotika
# 76        AHMAD GAND                                 Narkotika
# 77        AGUSDIANTO                                      KUHP
#
#                 Lokasi                     Lokasi asal             Status  \
# 0   Prabumulih Selatan               Polres Prabumulih     Menjadi Berkas
# ...

# %%
Bahan_pokok = pd.read_csv('C:/Users/asus/Documents/Prak.AI/harga-bahan-pokok-23-september-2015-edited.csv', index_col=1)
Bahan_pokok.head()
# Out:
#                             jenis_barang   pusat  selatan   timur   barat  \
# keterangan barang
# kg                                 Beras   11000    11000   10300    9500
# kg                            Gula Pasir   12500    13000   13000   13000
# liter                       Bimoli Botol   16000    14000   13500   13000
# kg                 Tanpa Merek ( Curah )   12000    13000   11500   10000
# kg                     Daging Sapi Murni  115000   110000  123000  100000
#
#                     utara  hari_ini  kemarin keterangan
# keterangan barang
# kg                  11000     10560    10520       NAIK
# kg                  12000     12700    12700      TURUN
# liter               13000     13900    13900       NAIK
# kg                  12000     11700    11700      TURUN
# kg                 110000    112000   110000       NAIK

# %% [markdown]
# MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# SCATTER PLOT

# %%
# create a figure and axis
fig, ax = plt.subplots()
ax.scatter(iris['Dewasa_pria'], iris['Dewasa_wanita'])
ax.set_title('Jumlah Penduduk')
ax.set_xlabel('Dewasa Pria')
ax.set_ylabel('Dewasa Wanita')
# Out:
# Text(0,0.5,'Dewasa Wanita')

# %%
# create color dictionary
colors = {'Mesoyi':'green', 'Talun':'yellow', 'Krompeng':'blue', 'Karangasem':'black' , 'Jumlah':'red' , 'Jolotigo':'blue' , 'Sengare': 'red', 'Donowangun':'black', 'Banjarsari':'brown',
         'Kalirejo':'gray','Batursari': 'brown'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(iris['Dewasa_pria'])):
    print (iris['Desa'][i])
    ax.scatter(iris['Dewasa_pria'][i], iris['Dewasa_wanita'][i], c=colors[iris['Desa'][i]])
# set a title and labels
ax.set_title('Jumlah Penduduk')
ax.set_xlabel('Dewasa Pria')
ax.set_ylabel('Dewasa Wanita')
# Out:
# Mesoyi
# Jolotigo
# Sengare
# Donowangun
# Talun
# Banjarsari
# Kalirejo
# Batursari
# Karangasem
# Krompeng
# Jumlah
# Mesoyi
# Jolotigo
# Sengare
# Text(0,0.5,'Dewasa Wanita')

# %% [markdown]
# LINE CHART

# %%
# get columns to plot
columns = iris.columns.drop(['Desa'])
# create x data
x_data = range(0,iris.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, iris[column], label=column)
# set title and legend
ax.set_title('Jumlah Penduduk')
ax.legend()

# %% [markdown]
# HISTOGRAM

# %%
# create figure and axis
fig, ax = plt.subplots()
# plot histogram
ax.hist(Bahan_pokok['pusat'])
# set title and labels
ax.set_title('Harga Bahan Pokok')
ax.set_xlabel('Harga')
ax.set_ylabel('Jenis Barang')
# Out:
# Text(0,0.5,'Jenis Barang')

# %% [markdown]
# BAR CHART

# %%
# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = Bahan_pokok['jenis_barang'].value_counts() 
# get x and y data 
points = data.index 
frequency = data.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
ax.set_title('Harga Bahan Pokok') 
ax.set_ylabel('Harga') 
ax.set_xlabel('Jenis Barang')
# Out:
# Text(0.5,0,'Jenis Barang')

# %% [markdown]
# PANDAS
# SCATTER PLOT

# %%
iris.plot.scatter(x='Dewasa_pria', y='Dewasa_wanita', title='Jumlah Penduduk')

# %% [markdown]
# LINE CHART

# %%
iris.drop(['Desa'], axis=1).plot.line(title='Jumlah Penduduk')

# %% [markdown]
# HISTOGRAM

# %%
Bahan_pokok['hari_ini'].plot.hist()

# %%
iris.plot.hist(subplots=True, layout=(2,3), figsize=(10, 10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001992C8DD908>,
# ...
#       dtype=object)

# %% [markdown]
# BAR CHART

# %%
Bahan_pokok['hari_ini'].plot.hist()

# %%
Bahan_pokok['hari_ini'].value_counts().sort_index().plot.bar(title='Bahan Pokok')

# %%
Bahan_pokok['hari_ini'].value_counts().sort_index().plot.barh(title='Bahan Pokok')

# %%
Bahan_pokok.groupby('jenis_barang').hari_ini.mean().sort_values(ascending=False)[:5].plot.bar()

# %% [markdown]
# SEABORN
# SCATTER PLOT

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Dewasa_pria', y='Dewasa_wanita', data=iris)

# %%
sns.scatterplot(x='Dewasa_pria', y='Dewasa_wanita', hue='Desa', data=iris)

# %% [markdown]
# LINE CHART

# %%
sns.lineplot(data=iris.drop(['Desa'], axis=1))

# %% [markdown]
# HISTOGRAM

# %%
sns.distplot(Bahan_pokok['hari_ini'], bins=10, kde=False)

# %%
sns.distplot(Bahan_pokok['hari_ini'], bins=10, kde=True)

# %% [markdown]
# BAR CHART

# %%
sns.countplot(Bahan_pokok['hari_ini'])

# %% [markdown]
# OTHER GRAPHS
# BOX PLOTS

# %%
import seaborn as sns
sns.set(color_codes=True)
df = Bahan_pokok[(Bahan_pokok['kemarin']>=95) & (Bahan_pokok['hari_ini']<1000)]
sns.boxplot(data=Bahan_pokok)

# %% [markdown]
# HEATMAP

# %%
import numpy as np

# get correlation matrix
corr = iris.corr()
fig, ax = plt.subplots()
# create heatmap
im = ax.imshow(corr.values)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
# get correlation matrix
corr = iris.corr()
fig, ax = plt.subplots()
# create heatmap
im = ax.imshow(corr.values)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="black")

# %%
sns.heatmap(iris.corr(), annot=True)

# %% [markdown]
# FACETING

# %%
g = sns.FacetGrid(iris, col='Desa')
g = g.map(sns.kdeplot, 'Dewasa_pria')
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\asus\Anaconda3\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\asus\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# C:\Users\asus\Anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %% [markdown]
# PAIRPLOT

# %%
sns.pairplot(iris)

# %%
from pandas.plotting import scatter_matrix

fig, ax = plt.subplots(figsize=(12,12))
scatter_matrix(iris, alpha=1, ax=ax)
# Out:
# C:\Users\asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   after removing the cwd from sys.path.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023495F2F898>,
# ...
#       dtype=object)

# %% [markdown]
# ANALISIS
#
# Setelah melakukan praktikum pada kali ini tentang 'Introduction to Data Visualization in Python' dapat dianalisis bahwa :
# 1. Mengimport 2 Datasets, dimana pada 2 dataset tersebut memiliki isi/data yang berbeda.
# 2. Menggunakan Matploib, Pandas dan Seaborn
# 3. Membuat scatter plot,coloring,line chart,histogram,bar chart,faceting,heat maps,box plot dan pairplot
# 4. Penggunaan versi seaborn pada jupyter notebook sangat berpengaruh pada hasil/output dari grafik, untuk menampilkan output
#    pada seaborn dibutuhkan versi 0.9.0 di seaborn dan 5.5 pada jupyter notebook.
